# %%
#importing relevant libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#loading data from local repo
datax = pd.read_csv("data_files/rawdata/neutrino2008.csv", sep=r"\s+")
datay = pd.read_csv("data_files/rawdata/events.csv" )

# %%
#inspecting raw data
print(datax.head())
print(datax.shape)
print(datax.columns)
print(datax.info)
print(datax.isnull().sum())
# Out:
#               #  MJD[days]  log10(E/GeV)  AngErr[deg]  RA[deg]  Dec[deg]  \
# 0  57891.176944       2.90          0.89      343.245   13.768    46.287
# 1  57891.180951       3.13          0.35      127.003   35.576   263.912
# 2  57891.188775       4.70          0.20      216.473  -23.266   177.292
# 3  57891.195600       3.02          3.26      176.624   31.430   219.626
# 4  57891.195746       3.26          0.38       42.288    4.950   354.022
#
#    Azimuth[deg]  Zenith[deg]
# 0       103.860          NaN
# 1       125.521          NaN
# 2        66.652          NaN
# 3       121.334          NaN
# 4        95.023          NaN
# (145750, 8)
# Index(['#', 'MJD[days]', 'log10(E/GeV)', 'AngErr[deg]', 'RA[deg]', 'Dec[deg]',
#        'Azimuth[deg]', 'Zenith[deg]'],
#       dtype='object')
# <bound method DataFrame.info of                    #  MJD[days]  log10(E/GeV)  AngErr[deg]  RA[deg]  Dec[deg]  \
# 0       57891.176944       2.90          0.89      343.245   13.768    46.287
# ...

# %%
#inspecting event raw data
print(datay.head())
print(datay.shape)
print(datay.columns)
print(datay.info)
print(datay.isnull().sum())
# Out:
#    id           mjd        ra       dec        f0        f1        f2  \
# 0   1  55351.322214  0.821759  0.113781  2.675354  0.659817  2.828038
# 1   2  55351.465966  3.391436 -0.158430  3.046346 -0.521871 -2.923539
# 2   3  55451.070748  2.231976 -0.605069  2.175865  2.231976  1.569496
# 3   4  55477.393098  2.899470 -0.832452  2.403248  2.899470 -2.829608
# 4   7  55571.258536  0.086326  0.236681  0.792669  0.417764  2.359098
#
#             f3          f4        f5        f6        f7 reconstruction  \
# 0     6.294721    8.556404 -0.768178  0.194403  0.588216         Shower
# 1    66.263620   78.794116 -0.505769  1.355302  1.573311         Shower
# 2  2242.302212  152.897262  1.000000  0.000000  0.000000          Track
# 3   253.119238   46.438723  1.000000  0.000000  0.000000         Shower
# 4    12.627479    6.862668 -0.666041  0.091236 -2.486959         Shower
#
#        energy    drlogl
# 0   44729.695 -0.023428
# 1  101722.300 -0.033503
# 2   67136.500 -0.936586
# ...
